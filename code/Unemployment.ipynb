# %%
import pandas as pd

# %%
#Load the data
df = pd.read_csv('../raw_data/unemployment.csv')
df.head(10)
# Out:
#      Date  Year  Month Month txt   All  16-24  25-54  55-64   65+  \
# 0  23-Feb  2023      2       Feb  0.04   0.08   0.03   0.02  0.03
# 1  23-Jan  2023      1       Jan  0.04   0.08   0.03   0.03  0.03
# 2  22-Dec  2022     12       Dec  0.04   0.08   0.03   0.03  0.03
# 3  22-Nov  2022     11       Nov  0.04   0.08   0.03   0.03  0.03
# 4  22-Oct  2022     10       Oct  0.04   0.08   0.03   0.03  0.03
# 5  22-Sep  2022      9       Sep  0.04   0.08   0.03   0.03  0.03
# 6  22-Aug  2022      8       Aug  0.04   0.08   0.03   0.03  0.03
# 7  22-Jul  2022      7       Jul  0.04   0.08   0.04   0.03  0.03
# 8  22-Jun  2022      6       Jun  0.04   0.09   0.04   0.03  0.03
# 9  22-May  2022      5       May  0.04   0.09   0.04   0.03  0.04
#
#    Less than HS  ...  White Men  White Men 16-24  White Men 25-54  \
# 0          0.07  ...       0.03             0.07             0.03
# 1          0.07  ...       0.03             0.07             0.03
# ...

# %%
#Check the data types
df.dtypes
# Out:
# Date                            object
# Year                             int64
# Month                            int64
# Month txt                       object
# All                            float64
#                                 ...
# White Men Less than HS         float64
# White Men High school          float64
# White Men Some college         float64
# White Men Bachelor's degree    float64
# White Men Advanced degree      float64
# Length: 124, dtype: object

# %%
#Filter the year
df=df.loc[(df["Year"]>1987)&(df["Year"]<2021)]

# %%
#Drop the NA
df_umemployment=df.dropna()
df_umemployment.head(10)
# Out:
#       Date  Year  Month Month txt   All  16-24  25-54  55-64   65+  \
# 26  20-Dec  2020     12       Dec  0.08   0.15   0.07   0.07  0.08
# 27  20-Nov  2020     11       Nov  0.08   0.15   0.07   0.06  0.07
# 28  20-Oct  2020     10       Oct  0.08   0.14   0.07   0.06  0.07
# 29  20-Sep  2020      9       Sep  0.07   0.14   0.06   0.06  0.07
# 30  20-Aug  2020      8       Aug  0.07   0.14   0.06   0.06  0.06
# 31  20-Jul  2020      7       Jul  0.07   0.13   0.06   0.05  0.06
# 32  20-Jun  2020      6       Jun  0.06   0.12   0.05   0.05  0.05
# 33  20-May  2020      5       May  0.05   0.11   0.05   0.04  0.05
# 34  20-Apr  2020      4       Apr  0.05   0.10   0.04   0.03  0.04
# 35  20-Mar  2020      3       Mar  0.04   0.08   0.03   0.03  0.03
#
#     Less than HS  ...  White Men  White Men 16-24  White Men 25-54  \
# 26          0.14  ...       0.06             0.12             0.06
# 27          0.13  ...       0.06             0.12             0.05
# ...

# %%
#Select columns
df_umemployment=df_umemployment[["Year","All","Women Bachelor's degree","Men Bachelor's degree","Less than HS","High school","Some college","Bachelor's degree","Advanced degree","Women","Men"]]

# %%
df_umemployment.head()
# Out:
#     Year   All  Women Bachelor's degree  Men Bachelor's degree  Less than HS  \
# 26  2020  0.08                     0.06                   0.05          0.14
# 27  2020  0.08                     0.06                   0.05          0.13
# 28  2020  0.08                     0.06                   0.05          0.13
# 29  2020  0.07                     0.06                   0.05          0.13
# 30  2020  0.07                     0.06                   0.05          0.12
#
#     High school  Some college  Bachelor's degree  Advanced degree  Women   Men
# 26         0.10          0.09               0.06             0.04   0.08  0.08
# 27         0.10          0.08               0.06             0.04   0.08  0.08
# 28         0.10          0.08               0.06             0.04   0.08  0.07
# 29         0.09          0.08               0.05             0.04   0.08  0.07
# 30         0.09          0.07               0.05             0.03   0.07  0.07

# %%
df_umemployment.tail()
# Out:
#      Year   All  Women Bachelor's degree  Men Bachelor's degree  Less than HS  \
# 417  1988  0.06                     0.03                   0.03          0.12
# 418  1988  0.06                     0.03                   0.03          0.12
# 419  1988  0.06                     0.03                   0.03          0.12
# 420  1988  0.06                     0.03                   0.03          0.12
# 421  1988  0.06                     0.03                   0.03          0.12
#
#      High school  Some college  Bachelor's degree  Advanced degree  Women  \
# 417         0.06          0.05               0.03             0.02   0.06
# 418         0.06          0.05               0.03             0.02   0.06
# 419         0.06          0.05               0.03             0.02   0.06
# 420         0.06          0.05               0.03             0.02   0.06
# 421         0.06          0.05               0.03             0.02   0.06
#
#       Men
# 417  0.06
# 418  0.06
# 419  0.06
# ...

# %%
#Change the names
df_umemployment=df_umemployment.rename(columns={"Year":"year","All":"all","Women Bachelor's degree":"women_b_degree","Men Bachelor's degree":"men_b_degree","Less than HS":"less_than_hs","High school":"hign_school","Some college":"some_college","Bachelor's degree":"bachelor_degree","Advanced degree":"advanced_degree","Women":"women","Men":"men"})

# %%
df_umemployment
# Out:
#      year   all  women_b_degree  men_b_degree  less_than_hs  hign_school  \
# 26   2020  0.08            0.06          0.05          0.14         0.10
# 27   2020  0.08            0.06          0.05          0.13         0.10
# 28   2020  0.08            0.06          0.05          0.13         0.10
# 29   2020  0.07            0.06          0.05          0.13         0.09
# 30   2020  0.07            0.06          0.05          0.12         0.09
# ..    ...   ...             ...           ...           ...          ...
# 417  1988  0.06            0.03          0.03          0.12         0.06
# 418  1988  0.06            0.03          0.03          0.12         0.06
# 419  1988  0.06            0.03          0.03          0.12         0.06
# 420  1988  0.06            0.03          0.03          0.12         0.06
# 421  1988  0.06            0.03          0.03          0.12         0.06
#
#      some_college  bachelor_degree  advanced_degree  women   men
# ...

# %%
#Group by years and get the average number 
df_umemployment=round(df_umemployment.groupby("year").mean().astype(float),3)

# %%
#Value sort by year
df_umemployment.sort_values("year",ascending=False)
# Out:
#         all  women_b_degree  men_b_degree  less_than_hs  hign_school  \
# year
# 2020  0.061           0.044         0.038         0.109        0.077
# 2019  0.040           0.023         0.030         0.080        0.050
# 2018  0.040           0.028         0.028         0.085        0.052
# 2017  0.048           0.030         0.030         0.097        0.060
# 2016  0.050           0.030         0.030         0.103        0.066
# 2015  0.057           0.036         0.032         0.118        0.071
# 2014  0.068           0.040         0.040         0.137        0.084
# 2013  0.079           0.047         0.044         0.159        0.097
# 2012  0.085           0.050         0.050         0.173        0.104
# 2011  0.092           0.050         0.057         0.183        0.114
# 2010  0.099           0.055         0.060         0.190        0.120
# 2009  0.078           0.042         0.045         0.159        0.094
# ...

# %%
#Output clean data
df_umemployment.to_csv('../clean_data/unemployment_clean.csv',index=True)
