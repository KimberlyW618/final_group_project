# %%
#Import the dependencies
import pandas as pd
from datetime import datetime

# %%
#Upload the raw data and test the first 10 rows
df = pd.read_csv('../raw_data/Labor-force participation rate.csv')
df.head(10)
# Out:
#      Date  Year Month Month txt     All   16-24   25-54   55-64     65+  \
# 0  23-Feb  2023     2       Feb  62.30%  55.80%  82.60%  65.20%  19.20%
# 1  23-Jan  2023     1       Jan  62.30%  55.60%  82.50%  65.20%  19.20%
# 2  22-Dec  2022    12       Dec  62.20%  55.60%  82.40%  65.20%  19.20%
# 3  22-Nov  2022    11       Nov  62.20%  55.60%  82.40%  65.10%  19.20%
# 4  22-Oct  2022    10       Oct  62.20%  55.60%  82.40%  65.10%  19.20%
# 5  22-Sep  2022     9       Sep  62.20%  55.70%  82.30%  65.00%  19.20%
# 6  22-Aug  2022     8       Aug  62.10%  55.70%  82.20%  65.00%  19.10%
# 7  22-Jul  2022     7       Jul  62.10%  55.60%  82.10%  65.00%  19.10%
# 8  22-Jun  2022     6       Jun  62.00%  55.60%  82.10%  65.00%  19.10%
# 9  22-May  2022     5       May  62.00%  55.60%  82.00%  65.00%  19.00%
#
#   Less than HS  ... White Men White Men 16-24 White Men 25-54 White Men 55-64  \
# 0       40.30%  ...    66.10%          58.70%          89.20%          71.60%
# ...

# %%
#Check the data types
df.dtypes
# Out:
# Date                           object
# Year                            int64
# Month                          object
# Month txt                      object
# All                            object
#                                 ...
# White Men Less than HS         object
# White Men High school          object
# White Men Some college         object
# White Men Bachelor's degree    object
# White Men Advanced degree      object
# Length: 124, dtype: object

# %%
#Select the year from 1987 to 2023
df.loc[df["Year"]>1987]
# Out:
#        Date  Year Month Month txt     All   16-24   25-54   55-64     65+  \
# 0    23-Feb  2023     2       Feb  62.30%  55.80%  82.60%  65.20%  19.20%
# 1    23-Jan  2023     1       Jan  62.30%  55.60%  82.50%  65.20%  19.20%
# 2    22-Dec  2022    12       Dec  62.20%  55.60%  82.40%  65.20%  19.20%
# 3    22-Nov  2022    11       Nov  62.20%  55.60%  82.40%  65.10%  19.20%
# 4    22-Oct  2022    10       Oct  62.20%  55.60%  82.40%  65.10%  19.20%
# ..      ...   ...   ...       ...     ...     ...     ...     ...     ...
# 417  May-88  1988     5       May  65.70%  68.30%  82.70%  54.50%  11.40%
# 418  Apr-88  1988     4       Apr  65.70%  68.50%  82.60%  54.60%  11.30%
# 419  Mar-88  1988     3       Mar  65.70%  68.50%  82.60%  54.60%  11.30%
# 420  Feb-88  1988     2       Feb  65.70%  68.50%  82.60%  54.50%  11.20%
# 421  Jan-88  1988     1       Jan  65.70%  68.50%  82.60%  54.50%  11.20%
#
#     Less than HS  ... White Men White Men 16-24 White Men 25-54  \
# ...

# %%
# Drop the NA and test the first 10 rows
df_labor_force_participation=df.dropna()
df_labor_force_participation.head(10)
# Out:
#      Date  Year Month Month txt     All   16-24   25-54   55-64     65+  \
# 0  23-Feb  2023     2       Feb  62.30%  55.80%  82.60%  65.20%  19.20%
# 1  23-Jan  2023     1       Jan  62.30%  55.60%  82.50%  65.20%  19.20%
# 2  22-Dec  2022    12       Dec  62.20%  55.60%  82.40%  65.20%  19.20%
# 3  22-Nov  2022    11       Nov  62.20%  55.60%  82.40%  65.10%  19.20%
# 4  22-Oct  2022    10       Oct  62.20%  55.60%  82.40%  65.10%  19.20%
# 5  22-Sep  2022     9       Sep  62.20%  55.70%  82.30%  65.00%  19.20%
# 6  22-Aug  2022     8       Aug  62.10%  55.70%  82.20%  65.00%  19.10%
# 7  22-Jul  2022     7       Jul  62.10%  55.60%  82.10%  65.00%  19.10%
# 8  22-Jun  2022     6       Jun  62.00%  55.60%  82.10%  65.00%  19.10%
# 9  22-May  2022     5       May  62.00%  55.60%  82.00%  65.00%  19.00%
#
#   Less than HS  ... White Men White Men 16-24 White Men 25-54 White Men 55-64  \
# 0       40.30%  ...    66.10%          58.70%          89.20%          71.60%
# ...

# %%
#Select the rows we want into a new df
df_labor_force_participation=df_labor_force_participation[["Date","Year","Month txt","All","Less than HS","High school","Some college","Bachelor's degree","Advanced degree","Women","Men"]]

# %%
#test the new df 
df_labor_force_participation.head()
# Out:
#      Date  Year Month txt     All Less than HS High school Some college  \
# 0  23-Feb  2023       Feb  62.30%       40.30%      58.20%       62.70%
# 1  23-Jan  2023       Jan  62.30%       40.20%      58.20%       62.70%
# 2  22-Dec  2022       Dec  62.20%       40.10%      58.20%       62.70%
# 3  22-Nov  2022       Nov  62.20%       40.10%      58.10%       62.70%
# 4  22-Oct  2022       Oct  62.20%       40.00%      58.10%       62.70%
#
#   Bachelor's degree Advanced degree   Women     Men
# 0            73.00%          73.50%  56.90%  68.00%
# 1            73.00%          73.50%  56.80%  68.00%
# 2            73.00%          73.50%  56.80%  68.00%
# 3            72.90%          73.50%  56.80%  67.90%
# 4            72.90%          73.50%  56.80%  67.90%

# %%
#test the new df last 10 rows to make sure the year is correct
df_labor_force_participation.tail(10)
# Out:
#        Date  Year Month txt     All Less than HS High school Some college  \
# 521  Sep-79  1979       Sep  63.80%       47.30%      69.60%       71.20%
# 522  Aug-79  1979       Aug  63.80%       47.30%      69.50%       71.20%
# 523  Jul-79  1979       Jul  63.70%       47.30%      69.40%       71.20%
# 524  Jun-79  1979       Jun  63.70%       47.40%      69.40%       71.20%
# 525  May-79  1979       May  63.70%       47.40%      69.30%       71.20%
# 526  Apr-79  1979       Apr  63.60%       47.50%      69.30%       71.20%
# 527  Mar-79  1979       Mar  63.60%       47.50%      69.20%       71.20%
# 528  Feb-79  1979       Feb  63.50%       47.50%      69.20%       71.10%
# 529  Jan-79  1979       Jan  63.40%       47.50%      69.10%       71.00%
# 530  Dec-78  1978       Dec  63.40%       47.40%      69.00%       70.80%
#
#     Bachelor's degree Advanced degree   Women     Men
# 521            77.60%          84.60%  51.00%  78.10%
# ...

# %%
# import out the clean data into new csv
df_labor_force_participation.to_csv('../clean_data/Labor_force_participation_rate_clean.csv')
