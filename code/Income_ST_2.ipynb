# %%
import pandas as pd
import os
import numpy as np

# %matplotlib inline

# %%
data = pd.read_csv("income_ST.csv")
data
# Out:
#     Unnamed: 0  United_States  Alabama   Alaska  Arizona  Arkansas  \
# 0         2021        70784.0  56929.0  81133.0  70821.0   50784.0
# 1         2020        68010.0  54689.0  74746.0  67088.0   50777.0
# 2         2019        68703.0  56200.0  78394.0  70674.0   54539.0
# 3         2018        63179.0  49936.0  68734.0  62283.0   49781.0
# 4         2017        61136.0  50865.0  77987.0  59700.0   49751.0
# 5         2016        59039.0  47221.0  75723.0  57100.0   45907.0
# 6         2015        56516.0  44509.0  75112.0  52248.0   42798.0
# 7         2014        53657.0  42278.0  67629.0  49254.0   44922.0
# 8         2013        51939.0  41381.0  61137.0  50602.0   39919.0
# 9         2012        51017.0  43464.0  63648.0  47044.0   39018.0
# 10        2011        50054.0  42590.0  57431.0  48621.0   41302.0
# 11        2010        49276.0  40933.0  57848.0  46896.0   38587.0
# 12        2009        49777.0  39980.0  61604.0  45739.0   36538.0
# ...

# %%
df = pd.DataFrame(data)

# %%
df2 = df.rename(columns={"Unnamed: 0":"year", "United_States":"avgerage"})

# %%
new_df = pd.melt(df2, id_vars=['year'], value_vars=['avgerage', 'Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'District_of_Columbia', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New_Hampsire', 'New_Jersey', 'New_Mexico', 'New_York', 'North_Carolina', 'North_Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode_Island', 'South_Carolina', 'South_Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virgina', 'Washington', 'West_Virgina', 'Wisconsin', 'Wyoming'])

# %%
new_df
# Out:
#       year  variable    value
# 0     2021  avgerage  70784.0
# 1     2020  avgerage  68010.0
# 2     2019  avgerage  68703.0
# 3     2018  avgerage  63179.0
# 4     2017  avgerage  61136.0
# ...    ...       ...      ...
# 1815  1991   Wyoming  29050.0
# 1816  1990   Wyoming  29460.0
# 1817  1989   Wyoming  29521.0
# 1818  1988   Wyoming  26419.0
# 1819  1987   Wyoming  27590.0
#
# [1820 rows x 3 columns]

# %%
t_df = new_df.rename(columns={"variable":"state", "value":"income"})

# %%
t_df.head()
# Out:
#    year     state   income
# 0  2021  avgerage  70784.0
# 1  2020  avgerage  68010.0
# 2  2019  avgerage  68703.0
# 3  2018  avgerage  63179.0
# 4  2017  avgerage  61136.0

# %%
t_df.dtypes
# Out:
# year        int64
# state      object
# income    float64
# dtype: object

# %%
t_df.to_csv('income_st_reshape.csv', index=False)
