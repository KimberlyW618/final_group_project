# %%
import os
import pandas as pd

# %%
df = pd.read_csv("Tuition_87.csv")
df
# Out:
#     year   public   private  public_tuiton _nflation  all_tuition_inflation  \
# 0   1987  1537.37   7116.11                    0.121                  0.124
# 1   1988  1646.19   7721.60                    0.121                  0.124
# 2   1989  1779.61   8396.33                    0.121                  0.124
# 3   1990  1888.13   9082.54                    0.774                  0.731
# 4   1991  2116.89   9759.44                    0.774                  0.731
# 5   1992  2349.11  10293.53                    0.774                  0.731
# 6   1993  2536.58  10952.22                    0.774                  0.731
# 7   1994  2680.72  11480.93                    0.774                  0.731
# 8   1995  2847.58  12243.16                    0.774                  0.731
# 9   1996  2987.22  12881.25                    0.774                  0.731
# 10  1997  3109.51  13344.25                    0.774                  0.731
# ...

# %%
df2 = df.drop(columns=['public_tuiton _nflation', 'all_tuition_inflation', 'public_x_inflation', 'privat_x_inflation'])

# %%
df2.dtypes
# Out:
# year         int64
# public     float64
# private    float64
# dtype: object

# %%
df2
# Out:
#     year   public   private
# 0   1987  1537.37   7116.11
# 1   1988  1646.19   7721.60
# 2   1989  1779.61   8396.33
# 3   1990  1888.13   9082.54
# 4   1991  2116.89   9759.44
# 5   1992  2349.11  10293.53
# 6   1993  2536.58  10952.22
# 7   1994  2680.72  11480.93
# 8   1995  2847.58  12243.16
# 9   1996  2987.22  12881.25
# 10  1997  3109.51  13344.25
# 11  1998  3228.72  13972.87
# 12  1999  3348.81  14616.05
# 13  2000  3500.52  15470.47
# 14  2001  3735.21  16210.89
# 15  2002  4046.17  16825.89
# 16  2003  4586.54  17763.20
# 17  2004  5026.55  18603.89
# 18  2005  5350.93  19291.66
# 19  2006  5666.22  20516.60
# 20  2007  5943.14  21426.67
# 21  2008  6311.84  22039.92
# 22  2009  6716.60  22269.29
# 23  2010  7131.85  22677.29
# 24  2011  7713.41  23463.67
# 25  2012  8070.19  24522.64
# 26  2013  8311.86  25706.76
# 27  2014  8543.35  26738.52
# 28  2015  8778.40  27941.60
# 29  2016  8804.40  29475.54
# 30  2017  9036.06  30722.61
# 31  2018  9211.80  31883.34
# ...

# %%
df2.to_csv('Tuition_87.csv', index=False)
